# %%
# !pip install faker
# Out:
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/1.9 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 4.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from faker import Faker
fake =Faker()

# %%
df = pd.read_csv('features.csv')

# %%
print("First 5 rows:\n", df.head())
print("\nLast 5 rows:\n", df.tail())
# Out:
# First 5 rows:
#     Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False
#
# Last 5 rows:
#        Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# ...

# %%
print("\nShape of the dataset:", df.shape)
# Out:
# Shape of the dataset: (8190, 12)

# %%
print("\nColumn names and data types:\n", df.dtypes)
# Out:
# Column names and data types:
#  Store             int64
# Date             object
# Temperature     float64
# Fuel_Price      float64
# MarkDown1       float64
# MarkDown2       float64
# MarkDown3       float64
# MarkDown4       float64
# MarkDown5       float64
# CPI             float64
# Unemployment    float64
# IsHoliday          bool
# dtype: object

# %%
print("\nMissing values in each column:\n", df.isnull().sum())
# Out:
# Missing values in each column:
#  Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
print("\nSummary statistics:\n", df.describe(include='all'))
# Out:
# Summary statistics:
#                Store        Date  Temperature   Fuel_Price      MarkDown1  \
# count   8190.000000        8190  8190.000000  8190.000000    4032.000000
# unique          NaN         182          NaN          NaN            NaN
# top             NaN  2010-02-05          NaN          NaN            NaN
# freq            NaN          45          NaN          NaN            NaN
# mean      23.000000         NaN    59.356198     3.405992    7032.371786
# std       12.987966         NaN    18.678607     0.431337    9262.747448
# min        1.000000         NaN    -7.290000     2.472000   -2781.450000
# 25%       12.000000         NaN    45.902500     3.041000    1577.532500
# 50%       23.000000         NaN    60.710000     3.513000    4743.580000
# 75%       34.000000         NaN    73.880000     3.743000    8923.310000
# max       45.000000         NaN   101.950000     4.468000  103184.980000
#
#             MarkDown2      MarkDown3     MarkDown4      MarkDown5  \
# ...

# %%
print("\nNumber of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
print("\nUnique values per column:\n", df.nunique())
# Out:
# Unique values per column:
#  Store             45
# Date             182
# Temperature     4178
# Fuel_Price      1011
# MarkDown1       4023
# MarkDown2       2715
# MarkDown3       2885
# MarkDown4       3405
# MarkDown5       4045
# CPI             2505
# Unemployment     404
# IsHoliday          2
# dtype: int64

# %%
df['CPI'].fillna(df['CPI'].mean(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_23720\1488988789.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CPI'].fillna(df['CPI'].mean(), inplace=True)

# %%
df_cleaned = df.dropna()

# %%
df['Temperature'].replace(0, pd.NA, inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_23720\3067669726.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Temperature'].replace(0, pd.NA, inplace=True)

# %%
df.drop(columns='MarkDown1', inplace=True)

# %%
df.rename(columns={'Fuel_Price': 'FuelRate'}, inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 0         1 2010-02-05        42.31     2.572        NaN        NaN
# 1         1 2010-02-12        38.51     2.548        NaN        NaN
# 2         1 2010-02-19        39.93     2.514        NaN        NaN
# 3         1 2010-02-26        46.63     2.561        NaN        NaN
# 4         1 2010-03-05        46.50     2.625        NaN        NaN
# ...     ...        ...          ...       ...        ...        ...
# 8185     45 2013-06-28        76.05     3.639     975.03       3.00
# 8186     45 2013-07-05        77.50     3.614    2268.58     582.74
# 8187     45 2013-07-12        79.37     3.614    1827.31      85.72
# 8188     45 2013-07-19        82.84     3.737    1047.07     204.19
# 8189     45 2013-07-26        76.06     3.804     851.73       2.06
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN  211.096358         8.106      False
# ...

# %%
df['Temperature_norm'] = (df['Temperature'] - df['Temperature'].min()) / (df['Temperature'].max() - df['Temperature'].min())

# %%
df
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 0         1 2010-02-05        42.31     2.572        NaN        NaN
# 1         1 2010-02-12        38.51     2.548        NaN        NaN
# 2         1 2010-02-19        39.93     2.514        NaN        NaN
# 3         1 2010-02-26        46.63     2.561        NaN        NaN
# 4         1 2010-03-05        46.50     2.625        NaN        NaN
# ...     ...        ...          ...       ...        ...        ...
# 8185     45 2013-06-28        76.05     3.639     975.03       3.00
# 8186     45 2013-07-05        77.50     3.614    2268.58     582.74
# 8187     45 2013-07-12        79.37     3.614    1827.31      85.72
# 8188     45 2013-07-19        82.84     3.737    1047.07     204.19
# 8189     45 2013-07-26        76.06     3.804     851.73       2.06
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0           NaN        NaN  211.096358         8.106      False
# ...

# %%
df['Temperature']
# Out:
# 0       42.31
# 1       38.51
# 2       39.93
# 3       46.63
# 4       46.50
#         ...
# 8185    76.05
# 8186    77.50
# 8187    79.37
# 8188    82.84
# 8189    76.06
# Name: Temperature, Length: 8190, dtype: float64

# %%
df[['Store', 'FuelRate']]
# Out:
#       Store  FuelRate
# 0         1     2.572
# 1         1     2.548
# 2         1     2.514
# 3         1     2.561
# 4         1     2.625
# ...     ...       ...
# 8185     45     3.639
# 8186     45     3.614
# 8187     45     3.614
# 8188     45     3.737
# 8189     45     3.804
#
# [8190 rows x 2 columns]

# %%
df[df['Temperature'] > 70]
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 13        1 2010-05-07        72.55     2.835        NaN        NaN
# 14        1 2010-05-14        74.78     2.854        NaN        NaN
# 15        1 2010-05-21        76.44     2.826        NaN        NaN
# 16        1 2010-05-28        80.44     2.759        NaN        NaN
# 17        1 2010-06-04        80.69     2.705        NaN        NaN
# ...     ...        ...          ...       ...        ...        ...
# 8185     45 2013-06-28        76.05     3.639     975.03       3.00
# 8186     45 2013-07-05        77.50     3.614    2268.58     582.74
# 8187     45 2013-07-12        79.37     3.614    1827.31      85.72
# 8188     45 2013-07-19        82.84     3.737    1047.07     204.19
# 8189     45 2013-07-26        76.06     3.804     851.73       2.06
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 13          NaN        NaN  210.339968         7.808      False
# ...

# %%
df[df['IsHoliday'] == True]
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 1         1 2010-02-12        38.51     2.548        NaN        NaN
# 31        1 2010-09-10        78.69     2.565        NaN        NaN
# 42        1 2010-11-26        64.52     2.735        NaN        NaN
# 47        1 2010-12-31        48.43     2.943        NaN        NaN
# 53        1 2011-02-11        36.39     3.022        NaN        NaN
# ...     ...        ...          ...       ...        ...        ...
# 8113     45 2012-02-10        37.00     3.640    6113.95       5.43
# 8143     45 2012-09-07        75.70     3.911      12.80      52.63
# 8154     45 2012-11-23        43.08     3.748        NaN   72542.01
# 8159     45 2012-12-28        35.96     3.563   24656.74     230.07
# 8165     45 2013-02-08        28.99     3.753     531.33      78.26
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 1           NaN        NaN  211.242170         8.106       True
# ...

# %%
df.sort_values(by='Temperature', ascending=True)
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 1246      7 2013-01-18        -7.29     2.889    3626.32       1.96
# 1245      7 2013-01-11        -6.61     2.957    8298.08       8.61
# 1244      7 2013-01-04        -6.08     3.034   11904.04      37.82
# 1144      7 2011-02-04        -2.06     3.011        NaN        NaN
# 3066     17 2013-01-18         0.25     2.914     691.28       3.98
# ...     ...        ...          ...       ...        ...        ...
# 5955     33 2012-08-10       100.07     3.811        NaN        NaN
# 5847     33 2010-07-16       100.14     2.971        NaN        NaN
# 2180     12 2013-07-05       101.95     3.753    1663.37     541.21
# 6912     38 2013-07-05       101.95     3.753        NaN     265.53
# 5092     28 2013-07-05       101.95     3.753     475.89     863.71
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 1246    1174.23    1513.31  200.738262         7.107      False
# ...

# %%
df.sort_values(by='Date')
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 0         1 2010-02-05        42.31     2.572        NaN        NaN
# 2730     16 2010-02-05        19.79     2.580        NaN        NaN
# 5460     31 2010-02-05        39.05     2.572        NaN        NaN
# 3640     21 2010-02-05        39.05     2.572        NaN        NaN
# 4550     26 2010-02-05         9.55     2.788        NaN        NaN
# ...     ...        ...          ...       ...        ...        ...
# 5823     32 2013-07-26        72.99     3.582     940.93      86.00
# 2365     13 2013-07-26        83.62     3.669    1377.41      93.40
# 5641     31 2013-07-26        85.00     3.620     138.71      12.00
# 6733     37 2013-07-26        83.28     3.620      11.86        NaN
# 8189     45 2013-07-26        76.06     3.804     851.73       2.06
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0           NaN        NaN  211.096358         8.106      False
# ...

# %%
df.sort_values(by='FuelRate', ascending=False)
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 7602     42 2012-10-12        76.03     4.468        NaN      10.87
# 2142     12 2012-10-12        71.74     4.468        NaN      16.75
# 6874     38 2012-10-12        71.74     4.468        NaN       8.66
# 1778     10 2012-10-12        76.03     4.468        NaN      10.32
# 5054     28 2012-10-12        71.74     4.468        NaN      13.36
# ...     ...        ...          ...       ...        ...        ...
# 6554     37 2010-02-19        45.66     2.514        NaN        NaN
# 184       2 2010-02-19        39.69     2.514        NaN        NaN
# 912       6 2010-02-19        43.58     2.514        NaN        NaN
# 6401     36 2010-09-10        80.58     2.513        NaN        NaN
# 6372     36 2010-02-19        45.66     2.472        NaN        NaN
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 7602        NaN     970.72  131.108333         6.943      False
# ...

# %%
df.sort_values(by=['Store', 'Temperature'])
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 49        1 2011-01-14        35.40     2.983        NaN        NaN
# 53        1 2011-02-11        36.39     3.022        NaN        NaN
# 1         1 2010-02-12        38.51     2.548        NaN        NaN
# 2         1 2010-02-19        39.93     2.514        NaN        NaN
# 152       1 2013-01-04        41.73     3.161   25366.33      15.01
# ...     ...        ...          ...       ...        ...        ...
# 8032     45 2010-07-23        81.46     2.771        NaN        NaN
# 8084     45 2011-07-22        82.33     3.811        NaN        NaN
# 8030     45 2010-07-09        82.45     2.793        NaN        NaN
# 8188     45 2013-07-19        82.84     3.737    1047.07     204.19
# 8134     45 2012-07-06        82.99     3.475     169.00      64.36
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 49          NaN        NaN  211.457411         7.742      False
# ...

# %%
df.sort_values(by='Temperature').head(3)
# Out:
#       Store       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 1246      7 2013-01-18        -7.29     2.889    3626.32       1.96
# 1245      7 2013-01-11        -6.61     2.957    8298.08       8.61
# 1244      7 2013-01-04        -6.08     3.034   11904.04      37.82
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 1246    1174.23    1513.31  200.738262         7.107      False
# 1245      15.26     745.42  200.619091         7.107      False
# 1244      65.08    1446.44  200.394083         7.107      False
#
#       Temperature_norm
# 1246          0.000000
# 1245          0.006225
# 1244          0.011077

# %%
df.rename(columns={'Store': 'Store_ID'}, inplace=True)

# %%
df
# Out:
#       Store_ID       Date  Temperature  FuelRate  MarkDown2  MarkDown3  \
# 0            1 2010-02-05        42.31     2.572        NaN        NaN
# 1            1 2010-02-12        38.51     2.548        NaN        NaN
# 2            1 2010-02-19        39.93     2.514        NaN        NaN
# 3            1 2010-02-26        46.63     2.561        NaN        NaN
# 4            1 2010-03-05        46.50     2.625        NaN        NaN
# ...        ...        ...          ...       ...        ...        ...
# 8185        45 2013-06-28        76.05     3.639     975.03       3.00
# 8186        45 2013-07-05        77.50     3.614    2268.58     582.74
# 8187        45 2013-07-12        79.37     3.614    1827.31      85.72
# 8188        45 2013-07-19        82.84     3.737    1047.07     204.19
# 8189        45 2013-07-26        76.06     3.804     851.73       2.06
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %%
df.rename(columns={'Temperature': 'Temp'}, inplace=True)

# %%
df
# Out:
#       Store_ID       Date   Temp  FuelRate  MarkDown2  MarkDown3  MarkDown4  \
# 0            1 2010-02-05  42.31     2.572        NaN        NaN        NaN
# 1            1 2010-02-12  38.51     2.548        NaN        NaN        NaN
# 2            1 2010-02-19  39.93     2.514        NaN        NaN        NaN
# 3            1 2010-02-26  46.63     2.561        NaN        NaN        NaN
# 4            1 2010-03-05  46.50     2.625        NaN        NaN        NaN
# ...        ...        ...    ...       ...        ...        ...        ...
# 8185        45 2013-06-28  76.05     3.639     975.03       3.00    2449.97
# 8186        45 2013-07-05  77.50     3.614    2268.58     582.74    5797.47
# 8187        45 2013-07-12  79.37     3.614    1827.31      85.72     744.84
# 8188        45 2013-07-19  82.84     3.737    1047.07     204.19     363.00
# 8189        45 2013-07-26  76.06     3.804     851.73       2.06      10.88
#
# ...

# %%
df.rename(columns={'FuelRate': 'Fuel_Cost', 'Date': 'Week_Date'}, inplace=True)

# %%
df.rename(columns={'MarkDown5': 'MD5'}, inplace=True)

# %%
df
# Out:
#       Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 0            1 2010-02-05  42.31      2.572        NaN        NaN        NaN
# 1            1 2010-02-12  38.51      2.548        NaN        NaN        NaN
# 2            1 2010-02-19  39.93      2.514        NaN        NaN        NaN
# 3            1 2010-02-26  46.63      2.561        NaN        NaN        NaN
# 4            1 2010-03-05  46.50      2.625        NaN        NaN        NaN
# ...        ...        ...    ...        ...        ...        ...        ...
# 8185        45 2013-06-28  76.05      3.639     975.03       3.00    2449.97
# 8186        45 2013-07-05  77.50      3.614    2268.58     582.74    5797.47
# 8187        45 2013-07-12  79.37      3.614    1827.31      85.72     744.84
# 8188        45 2013-07-19  82.84      3.737    1047.07     204.19     363.00
# 8189        45 2013-07-26  76.06      3.804     851.73       2.06      10.88
#
# ...

# %%
df['Temp'].mean()
# Out:
# 59.356197802197805

# %%
df['Fuel_Cost'].sum()
# Out:
# 27895.072999999997

# %%
df['IsHoliday'].value_counts()
# Out:
# IsHoliday
# False    7605
# True      585
# Name: count, dtype: int64

# %%
df.groupby('Store_ID')['Temp'].sum()
# Out:
# Store_ID
# 1     12177.99
# 2     12144.57
# 3     12811.74
# 4     11177.83
# 5     12416.86
# 6     12467.85
# 7      6901.67
# 8     11134.80
# 9     12061.05
# 10    12981.90
# 11    12961.55
# 12    12603.81
# 13     9520.13
# 14    10238.62
# 15     9158.83
# 16     7895.63
# 17     8207.09
# 18     9439.67
# 19     9256.58
# 20     9807.36
# 21    12268.15
# 22     9730.49
# 23     8599.18
# 24     9556.85
# 25     9244.23
# 26     7692.95
# 27    10159.57
# 28    12603.81
# 29     9730.49
# 30    12268.15
# 31    12268.15
# 32     9322.68
# 33    13729.73
# 34    10575.64
# 35    10159.57
# 36    12782.28
# 37    12782.28
# 38    12603.81
# 39    12684.56
# 40     8402.55
# 41     8549.43
# 42    12981.90
# 43    12306.53
# 44     9520.13
# 45    10238.62
# Name: Temp, dtype: float64

# %%
df['Temp'].max()
# Out:
# 101.95

# %%
df['Fuel_Cost'].min()
# Out:
# 2.472

# %%
df.groupby('Store_ID')['Temp'].mean().plot(kind='bar', figsize=(10,5))
plt.title("Average Temperature by Store")
plt.ylabel("Temperature")
plt.xlabel("Store")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 2
#       1 df.groupby('Store_ID')['Temp'].mean().plot(kind='bar', figsize=(10,5))
# ----> 2 plt.title("Average Temperature by Store")
#       3 plt.ylabel("Temperature")
#       4 plt.xlabel("Store")
#
# NameError: name 'plt' is not defined

# %%
df.sort_values('Week_Date').set_index('Week_Date')['Temp'].plot()
plt.title("Temperature Over Time")
plt.ylabel("Temperature")
plt.xlabel("Date")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 df.sort_values('Week_Date').set_index('Week_Date')['Temp'].plot()
# ----> 2 plt.title("Temperature Over Time")
#       3 plt.ylabel("Temperature")
#       4 plt.xlabel("Date")
#
# NameError: name 'plt' is not defined

# %%
df['Temp'].plot(kind='hist', bins=30)
plt.title("Distribution of Temperature")
plt.xlabel("Temperature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 df['Temp'].plot(kind='hist', bins=30)
# ----> 2 plt.title("Distribution of Temperature")
#       3 plt.xlabel("Temperature")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df['IsHoliday'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Holiday vs Non-Holiday")
plt.ylabel("")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 2
#       1 df['IsHoliday'].value_counts().plot.pie(autopct='%1.1f%%')
# ----> 2 plt.title("Holiday vs Non-Holiday")
#       3 plt.ylabel("")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.plot.scatter(x='Temp', y='Fuel_Cost')
plt.title("Temperature vs Fuel Cost")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 2
#       1 df.plot.scatter(x='Temp', y='Fuel_Cost')
# ----> 2 plt.title("Temperature vs Fuel Cost")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.boxplot(x=df['Temp'])
plt.title("Boxplot of Temperature")
plt.show()

# %%
df['Store_ID'] = df['Store_ID'].astype(str).str.lower()

# %%
df
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 0           1 2010-02-05  42.31      2.572        NaN        NaN        NaN
# 1           1 2010-02-12  38.51      2.548        NaN        NaN        NaN
# 2           1 2010-02-19  39.93      2.514        NaN        NaN        NaN
# 3           1 2010-02-26  46.63      2.561        NaN        NaN        NaN
# 4           1 2010-03-05  46.50      2.625        NaN        NaN        NaN
# ...       ...        ...    ...        ...        ...        ...        ...
# 8185       45 2013-06-28  76.05      3.639     975.03       3.00    2449.97
# 8186       45 2013-07-05  77.50      3.614    2268.58     582.74    5797.47
# 8187       45 2013-07-12  79.37      3.614    1827.31      85.72     744.84
# 8188       45 2013-07-19  82.84      3.737    1047.07     204.19     363.00
# 8189       45 2013-07-26  76.06      3.804     851.73       2.06      10.88
#
# ...

# %%
df['Store_ID_Short'] = df['Store_ID'].str[:3]

# %%
df['First_Name'] = ['John'] * len(df)
df['Last_Name'] = ['Doe'] * len(df)

# %%
df['Full_Name'] = df['First_Name'] + ' ' + df['Last_Name']

# %%
df['Full_Name'] = df['Full_Name'].str.replace(' ', '_')

# %%
df
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 0           1 2010-02-05  42.31      2.572        NaN        NaN        NaN
# 1           1 2010-02-12  38.51      2.548        NaN        NaN        NaN
# 2           1 2010-02-19  39.93      2.514        NaN        NaN        NaN
# 3           1 2010-02-26  46.63      2.561        NaN        NaN        NaN
# 4           1 2010-03-05  46.50      2.625        NaN        NaN        NaN
# ...       ...        ...    ...        ...        ...        ...        ...
# 8185       45 2013-06-28  76.05      3.639     975.03       3.00    2449.97
# 8186       45 2013-07-05  77.50      3.614    2268.58     582.74    5797.47
# 8187       45 2013-07-12  79.37      3.614    1827.31      85.72     744.84
# 8188       45 2013-07-19  82.84      3.737    1047.07     204.19     363.00
# 8189       45 2013-07-26  76.06      3.804     851.73       2.06      10.88
#
# ...

# %%
df.iloc[0]
# Out:
# Store_ID                              1
# Week_Date           2010-02-05 00:00:00
# Temp                              42.31
# Fuel_Cost                         2.572
# MarkDown2                           NaN
# MarkDown3                           NaN
# MarkDown4                           NaN
# MD5                                 NaN
# CPI                          211.096358
# Unemployment                      8.106
# IsHoliday                         False
# Temperature_norm               0.454046
# Store_ID_Short                        1
# First_Name                         John
# Last_Name                           Doe
# Full_Name                      John_Doe
# Name: 0, dtype: object

# %%
df.iloc[-3:]
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 8187       45 2013-07-12  79.37      3.614    1827.31      85.72     744.84
# 8188       45 2013-07-19  82.84      3.737    1047.07     204.19     363.00
# 8189       45 2013-07-26  76.06      3.804     851.73       2.06      10.88
#
#           MD5         CPI  Unemployment  IsHoliday  Temperature_norm  \
# 8187  2150.36  172.460809           NaN      False          0.793299
# 8188  1059.46  172.460809           NaN      False          0.825064
# 8189  1864.57  172.460809           NaN      False          0.762999
#
#      Store_ID_Short First_Name Last_Name Full_Name
# 8187             45       John       Doe  John_Doe
# 8188             45       John       Doe  John_Doe
# 8189             45       John       Doe  John_Doe

# %%
df.iloc[:5, :3]
# Out:
#   Store_ID  Week_Date   Temp
# 0        1 2010-02-05  42.31
# 1        1 2010-02-12  38.51
# 2        1 2010-02-19  39.93
# 3        1 2010-02-26  46.63
# 4        1 2010-03-05  46.50

# %%
df.iloc[:, 1:3]
# Out:
#       Week_Date   Temp
# 0    2010-02-05  42.31
# 1    2010-02-12  38.51
# 2    2010-02-19  39.93
# 3    2010-02-26  46.63
# 4    2010-03-05  46.50
# ...         ...    ...
# 8185 2013-06-28  76.05
# 8186 2013-07-05  77.50
# 8187 2013-07-12  79.37
# 8188 2013-07-19  82.84
# 8189 2013-07-26  76.06
#
# [8190 rows x 2 columns]

# %%
df.iloc[3, 1]
# Out:
# Timestamp('2010-02-26 00:00:00')

# %%
df.iloc[2:6, 1:5]
# Out:
#    Week_Date   Temp  Fuel_Cost  MarkDown2
# 2 2010-02-19  39.93      2.514        NaN
# 3 2010-02-26  46.63      2.561        NaN
# 4 2010-03-05  46.50      2.625        NaN
# 5 2010-03-12  57.79      2.667        NaN

# %%
df['Name'] = ['Alice', 'Bob', 'Charlie', 'David', 'Eva'] * (len(df) // 5) + ['Alice'] * (len(df) % 5)
df['City'] = ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'] * (len(df) // 5) + ['New York'] * (len(df) % 5)
df['Age'] = df['Temp'].astype(int)

# %%
df
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 0           1 2010-02-05  42.31      2.572        NaN        NaN        NaN
# 1           1 2010-02-12  38.51      2.548        NaN        NaN        NaN
# 2           1 2010-02-19  39.93      2.514        NaN        NaN        NaN
# 3           1 2010-02-26  46.63      2.561        NaN        NaN        NaN
# 4           1 2010-03-05  46.50      2.625        NaN        NaN        NaN
# ...       ...        ...    ...        ...        ...        ...        ...
# 8185       45 2013-06-28  76.05      3.639     975.03       3.00    2449.97
# 8186       45 2013-07-05  77.50      3.614    2268.58     582.74    5797.47
# 8187       45 2013-07-12  79.37      3.614    1827.31      85.72     744.84
# 8188       45 2013-07-19  82.84      3.737    1047.07     204.19     363.00
# 8189       45 2013-07-26  76.06      3.804     851.73       2.06      10.88
#
# ...

# %%
df.loc[df['Name'] == 'Alice']
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 0           1 2010-02-05  42.31      2.572        NaN        NaN        NaN
# 5           1 2010-03-12  57.79      2.667        NaN        NaN        NaN
# 10          1 2010-04-16  66.32      2.808        NaN        NaN        NaN
# 15          1 2010-05-21  76.44      2.826        NaN        NaN        NaN
# 20          1 2010-06-25  84.34      2.653        NaN        NaN        NaN
# ...       ...        ...    ...        ...        ...        ...        ...
# 8165       45 2013-02-08  28.99      3.753     531.33      78.26   24823.94
# 8170       45 2013-03-15  42.81      3.834        NaN      11.08     912.87
# 8175       45 2013-04-19  56.27      3.676      39.89      44.38      60.83
# 8180       45 2013-05-24  67.11      3.627     481.82      58.48    1183.23
# 8185       45 2013-06-28  76.05      3.639     975.03       3.00    2449.97
#
# ...

# %%
df.loc[df['Age'] > 30]
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 0           1 2010-02-05  42.31      2.572        NaN        NaN        NaN
# 1           1 2010-02-12  38.51      2.548        NaN        NaN        NaN
# 2           1 2010-02-19  39.93      2.514        NaN        NaN        NaN
# 3           1 2010-02-26  46.63      2.561        NaN        NaN        NaN
# 4           1 2010-03-05  46.50      2.625        NaN        NaN        NaN
# ...       ...        ...    ...        ...        ...        ...        ...
# 8185       45 2013-06-28  76.05      3.639     975.03       3.00    2449.97
# 8186       45 2013-07-05  77.50      3.614    2268.58     582.74    5797.47
# 8187       45 2013-07-12  79.37      3.614    1827.31      85.72     744.84
# 8188       45 2013-07-19  82.84      3.737    1047.07     204.19     363.00
# 8189       45 2013-07-26  76.06      3.804     851.73       2.06      10.88
#
# ...

# %%
df.loc[df['Age'].between(20, 40), 'City']
# Out:
# 1       Los Angeles
# 2           Chicago
# 49          Phoenix
# 53          Houston
# 182         Chicago
#            ...
# 8167        Chicago
# 8168        Houston
# 8169        Phoenix
# 8171    Los Angeles
# 8172        Chicago
# Name: City, Length: 1377, dtype: object

# %%
df.loc[df['City'] == 'New York']
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 0           1 2010-02-05  42.31      2.572        NaN        NaN        NaN
# 5           1 2010-03-12  57.79      2.667        NaN        NaN        NaN
# 10          1 2010-04-16  66.32      2.808        NaN        NaN        NaN
# 15          1 2010-05-21  76.44      2.826        NaN        NaN        NaN
# 20          1 2010-06-25  84.34      2.653        NaN        NaN        NaN
# ...       ...        ...    ...        ...        ...        ...        ...
# 8165       45 2013-02-08  28.99      3.753     531.33      78.26   24823.94
# 8170       45 2013-03-15  42.81      3.834        NaN      11.08     912.87
# 8175       45 2013-04-19  56.27      3.676      39.89      44.38      60.83
# 8180       45 2013-05-24  67.11      3.627     481.82      58.48    1183.23
# 8185       45 2013-06-28  76.05      3.639     975.03       3.00    2449.97
#
# ...

# %%
df.loc[0, ['Name', 'City']]
# Out:
# Name       Alice
# City    New York
# Name: 0, dtype: object

# %%
df.loc[(df['Age'] > 25) & (df['City'] == 'Los Angeles')]
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 1           1 2010-02-12  38.51      2.548        NaN        NaN        NaN
# 6           1 2010-03-19  54.58      2.720        NaN        NaN        NaN
# 11          1 2010-04-23  64.84      2.795        NaN        NaN        NaN
# 16          1 2010-05-28  80.44      2.759        NaN        NaN        NaN
# 21          1 2010-07-02  80.91      2.669        NaN        NaN        NaN
# ...       ...        ...    ...        ...        ...        ...        ...
# 8166       45 2013-02-15  35.87      3.814    2017.68       0.36    5012.39
# 8171       45 2013-03-22  36.55      3.800        NaN     308.00    1764.47
# 8176       45 2013-04-26  50.64      3.615        NaN      57.52      40.51
# 8181       45 2013-05-31  65.88      3.646     411.38      77.06       9.38
# 8186       45 2013-07-05  77.50      3.614    2268.58     582.74    5797.47
#
# ...

# %%
df['City'] = df['City'].replace('New York', 'NYC')

# %%
df['Age'] = df['Age'].replace(0, np.nan)

# %%
df
# Out:
#      Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  MarkDown4  \
# 0           1 2010-02-05  42.31      2.572        NaN        NaN        NaN
# 1           1 2010-02-12  38.51      2.548        NaN        NaN        NaN
# 2           1 2010-02-19  39.93      2.514        NaN        NaN        NaN
# 3           1 2010-02-26  46.63      2.561        NaN        NaN        NaN
# 4           1 2010-03-05  46.50      2.625        NaN        NaN        NaN
# ...       ...        ...    ...        ...        ...        ...        ...
# 8185       45 2013-06-28  76.05      3.639     975.03       3.00    2449.97
# 8186       45 2013-07-05  77.50      3.614    2268.58     582.74    5797.47
# 8187       45 2013-07-12  79.37      3.614    1827.31      85.72     744.84
# 8188       45 2013-07-19  82.84      3.737    1047.07     204.19     363.00
# 8189       45 2013-07-26  76.06      3.804     851.73       2.06      10.88
#
# ...

# %%
df.replace(100, 50, inplace=True)

# %%
df['Priority'] = ['High', 'Low', 'Medium', 'Low', 'High'] * (len(df) // 5)
df['Priority'] = df['Priority'].replace({'High': 'Medium', 'Low': 'Small'})

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_23720\1698716155.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.set_index('Name', inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.set_index(['City', 'Age'], inplace=True)

# %%
print(df.loc[('NYC', 35)])
# Out:
#             Name Store_ID  Week_Date   Temp  Fuel_Cost  MarkDown2  MarkDown3  \
# City Age
# NYC  35.0  Alice        7 2013-04-26  35.70      3.568        NaN      54.04
#      35.0  Alice       15 2011-12-16  35.49      3.611      19.00     158.53
#      35.0  Alice       16 2011-04-01  35.75      3.461        NaN        NaN
#      35.0  Alice       18 2012-01-13  35.25      3.523   22411.40      10.54
#      35.0  Alice       22 2010-02-26  35.98      2.753        NaN        NaN
#      35.0  Alice       22 2012-01-27  35.68      3.568    4022.06        NaN
#      35.0  Alice       25 2012-02-24  35.51      3.739    7242.90        NaN
#      35.0  Alice       26 2011-10-28  35.06      3.604        NaN        NaN
#      35.0  Alice       26 2012-03-16  35.06      3.867     161.00       3.99
#      35.0  Alice       27 2013-02-15  35.13      4.006   14425.39     243.52
#      35.0  Alice       27 2013-03-22  35.43      3.999        NaN     749.50
# ...

# %%
print(type(df.index))
print(df.index.is_unique)
# Out:
# <class 'pandas.core.indexes.multi.MultiIndex'>
# False

# %%
df.reset_index(inplace=True)
df.index = [f'Row_{i+1}' for i in range(len(df))]

# %%
print(df.groupby('City')['Age'].mean())
# Out:
# City
# Chicago        58.858364
# Houston        58.888278
# Los Angeles    58.911389
# NYC            58.870574
# Phoenix        58.748474
# Name: Age, dtype: float64

# %%
print(df.groupby('Age')['Gender'].count())
# Out:
# Age
# -7.0      1
# -6.0      2
# -2.0      1
#  2.0      2
#  4.0      1
#          ..
#  96.0     9
#  97.0     7
#  98.0     2
#  99.0     6
#  101.0    3
# Name: Gender, Length: 102, dtype: int64

# %%
print(df.groupby('Priority')['Fuel_Cost'].sum())
# Out:
# Priority
# Medium    16737.699
# Small     11157.374
# Name: Fuel_Cost, dtype: float64

# %%
print(df.groupby('Age')['Fuel_Cost'].sum())
# Out:
# Age
# -7.0       2.889
# -6.0       5.991
# -2.0       3.011
#  2.0       6.174
#  4.0       2.872
#            ...
#  96.0     31.255
#  97.0     22.792
#  98.0      7.717
#  99.0     20.550
#  101.0    11.259
# Name: Fuel_Cost, Length: 102, dtype: float64

# %%
print(df.groupby('City')['Full_Name'].nunique())
# Out:
# City
# Chicago        1
# Houston        1
# Los Angeles    1
# NYC            1
# Phoenix        1
# Name: Full_Name, dtype: int64

# %%
print(df.groupby('City')['Age'].max())
# Out:
# City
# Chicago        101.0
# Houston         99.0
# Los Angeles     99.0
# NYC            101.0
# Phoenix         98.0
# Name: Age, dtype: float64

# %%
print(df.groupby('City')['Age'].agg(['mean', 'median']))
# Out:
#                   mean  median
# City
# Chicago      58.858364    60.0
# Houston      58.888278    60.0
# Los Angeles  58.911389    60.0
# NYC          58.870574    60.0
# Phoenix      58.748474    60.0

# %%
print(df.groupby('Priority')['Fuel_Cost'].agg(['sum', 'mean', 'count']))
# Out:
#                 sum      mean  count
# Priority
# Medium    16737.699  3.406125   4914
# Small     11157.374  3.405792   3276

# %%
print(df.groupby('City')['Fuel_Cost'].agg(['min', 'max']))
# Out:
#                min    max
# City
# Chicago      2.472  4.468
# Houston      2.514  4.468
# Los Angeles  2.513  4.308
# NYC          2.514  4.449
# Phoenix      2.514  4.468

# %%
df.groupby('City')['Age'].agg(lambda x: x.max() - x.min())
# Out:
# City
# Chicago         97.0
# Houston         97.0
# Los Angeles    106.0
# NYC            107.0
# Phoenix        104.0
# Name: Age, dtype: float64

# %%
print(df.groupby('Priority').agg({'Fuel_Cost': 'mean', 'Temp': 'sum'}))
# Out:
#           Fuel_Cost       Temp
# Priority
# Medium     3.406125  291610.24
# Small      3.405792  194517.02

# %%
print(df.groupby('City')['Temp'].agg(['std', 'var']))
# Out:
#                    std         var
# City
# Chicago      18.714308  350.225318
# Houston      18.792067  353.141782
# Los Angeles  18.565536  344.679137
# NYC          18.665594  348.404382
# Phoenix      18.677221  348.838598

# %%
fake_data = pd.DataFrame({
    'Name': [fake.name() for _ in range(100)],
    'Address': [fake.address() for _ in range(100)],
    'Date': [fake.date() for _ in range(100)]
})

# %%
name_list = [fake.name() for _ in range(20)]
df_names = pd.DataFrame({'Name': name_list})

# %%
df_names['Email'] = [fake.email() for _ in range(20)]

# %%
df_names['DOB'] = [fake.date_of_birth(minimum_age=18, maximum_age=60) for _ in range(20)]
df_names['Age'] = pd.to_datetime('today').year - pd.to_datetime(df_names['DOB']).dt.year

# %%
df_products = pd.DataFrame({
    'Product_Name': [fake.word() for _ in range(10)],
    'Price': [round(fake.pyfloat(left_digits=3, right_digits=2, positive=True), 2) for _ in range(10)]
})

# %%
product_data = pd.DataFrame({
    'Product_ID': range(1, 6),
    'Product_Name': ['A', 'B', 'C', 'D', 'E']
})

sales_data = pd.DataFrame({
    'Product_ID': [1, 2, 3, 6],
    'Sales': [100, 200, 300, 400]
})

# %%
pd.merge(product_data, sales_data, on='Product_ID')
# Out:
#    Product_ID Product_Name  Sales
# 0           1            A    100
# 1           2            B    200
# 2           3            C    300

# %%
pd.merge(product_data, sales_data, on='Product_ID', how='left')
# Out:
#    Product_ID Product_Name  Sales
# 0           1            A  100.0
# 1           2            B  200.0
# 2           3            C  300.0
# 3           4            D    NaN
# 4           5            E    NaN

# %%
pd.merge(product_data, sales_data, how='left', on='Product_ID')
# Out:
#    Product_ID Product_Name  Sales
# 0           1            A  100.0
# 1           2            B  200.0
# 2           3            C  300.0
# 3           4            D    NaN
# 4           5            E    NaN

# %%
df1 = pd.DataFrame({'City': ['NYC'], 'Age': [35]})
df2 = pd.DataFrame({'City': ['NYC'], 'Age': [35], 'Sales': [100]})
pd.merge(df1, df2, on=['City', 'Age'])
# Out:
#   City  Age  Sales
# 0  NYC   35    100

# %%
left = pd.DataFrame({'Country': ['USA', 'Canada'], 'Value': [1, 2]})
right = pd.DataFrame({'Country': ['USA', 'UK'], 'Rank': [10, 20]})
pd.merge(left, right, on='Country', how='inner')
# Out:
#   Country  Value  Rank
# 0     USA      1    10

# %%
pd.merge(left, right, on='Country', how='outer')
# Out:
#   Country  Value  Rank
# 0  Canada    2.0   NaN
# 1      UK    NaN  20.0
# 2     USA    1.0  10.0

# %%
df.to_csv('updated_features.csv', index=False)

# %%
df.to_excel('updated_features.xlsx', index=False)

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...
